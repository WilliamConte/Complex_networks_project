# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import igraph as ig
from io import StringIO
import glob
import os
from helper_functions import *
from extract_data_pipeline import *
from extract_data_pipeline_no_topology import *

# %%
file_pattern_topologies = "./london-tube/London-topologies/London-*-adjacency-number.txt"
file_lines = None
line_prefixes = ["bakerloo","central","circle","district","hammersmith","jubilee","metropolitan",
                 "northern","piccadilly","victoria","waterloo"]
filename_nodes = "./london-tube/tube-stations-positions-years.txt"

city_path = "./london-tube"
file_prefix = "tube-"
file_suffix = ".txt"

output_edges = "London_edgelist.csv"
output_nodes = "London_nodelist.csv"

extract_data_pipeline_no_topology(file_pattern_topologies, file_lines, filename_nodes, output_edges, output_nodes, city_path = city_path, 
                      file_prefix = file_prefix, file_suffix = file_suffix,  line_prefixes=line_prefixes, more_files = True)
# Out:
# Processing: ./london-tube/London-topologies/London-1863-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1864-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1865-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1866-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1867-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1868-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1869-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1870-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1871-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1872-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1873-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1874-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1875-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1876-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1877-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1878-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1879-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1880-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1881-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1882-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1883-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1884-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1885-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1886-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1887-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1888-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1889-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1890-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1891-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1892-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1893-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1894-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1895-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1896-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1897-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1898-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1899-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1900-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1901-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1902-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1903-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1904-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1905-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1906-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1907-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1908-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1909-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1910-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1911-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1912-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1913-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1914-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1915-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1916-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1917-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1918-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1919-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1920-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1921-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1922-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1923-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1924-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1925-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1926-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1927-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1928-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1929-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1930-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1931-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1932-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1933-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1934-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1935-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1936-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1937-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1938-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1939-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1940-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1941-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1942-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1943-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1944-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1945-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1946-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1947-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1948-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1949-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1950-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1951-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1952-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1953-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1954-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1955-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1956-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1957-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1958-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1959-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1960-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1961-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1962-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1963-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1964-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1965-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1966-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1967-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1968-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1969-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1970-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1971-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1972-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1973-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1974-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1975-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1976-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1977-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1978-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1979-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1980-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1981-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1982-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1983-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1984-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1985-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1986-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1987-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1988-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1989-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1990-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1991-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1992-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1993-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1994-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1995-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1996-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1997-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1998-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-1999-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-2000-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-2001-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-2002-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-2003-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-2004-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-2005-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-2006-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-2007-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-2008-adjacency-number.txt
# Processing: ./london-tube/London-topologies/London-2009-adjacency-number.txt
# ./london-tube/tube-bakerloo*.txt
# ./london-tube/tube-central*.txt
# ./london-tube/tube-circle*.txt
# ./london-tube/tube-district*.txt
# ./london-tube/tube-hammersmith*.txt
# ./london-tube/tube-jubilee*.txt
# ./london-tube/tube-metropolitan*.txt
# ./london-tube/tube-northern*.txt
# ./london-tube/tube-piccadilly*.txt
# ./london-tube/tube-victoria*.txt
# ./london-tube/tube-waterloo*.txt
# Processing: ./london-tube/tube-bakerloo.txt
# Processing: ./london-tube/tube-central.txt
# Processing: ./london-tube/tube-circle.txt
# Processing: ./london-tube/tube-district.txt
# Processing: ./london-tube/tube-hammersmith.txt
# Processing: ./london-tube/tube-jubilee.txt
# Processing: ./london-tube/tube-metropolitan.txt
# Processing: ./london-tube/tube-northern.txt
# Processing: ./london-tube/tube-piccadilly.txt
# Processing: ./london-tube/tube-victoria.txt
# Processing: ./london-tube/tube-waterloo.txt
# ['circle', 'hammersmith', 'metropolitan']
# ['circle', 'hammersmith', 'metropolitan']
# ['circle', 'hammersmith', 'metropolitan']
# ['circle', 'hammersmith', 'metropolitan']
# []
# ['bakerloo', 'circle', 'hammersmith']
# []
# ['circle', 'hammersmith']
# ['circle', 'hammersmith', 'metropolitan']
# ['circle', 'hammersmith', 'metropolitan']
# ['hammersmith']
# []
# []
# ['circle']
# []
# ['circle', 'district', 'piccadilly']
# ['circle', 'district']
# ['circle', 'district']
# ['circle', 'district']
# ['circle', 'district']
# ['hammersmith']
# []
# ['circle', 'district']
# ['circle', 'district']
# ['circle', 'district']
# ['district', 'piccadilly']
# ['hammersmith']
# ['hammersmith']
# ['district']
# ['circle', 'district']
# ['district']
# ['district']
# ['district']
# ['circle', 'hammersmith', 'metropolitan']
# ['circle', 'metropolitan']
# ['district']
# []
# ['district']
# ['district']
# []
# ['district']
# ['district']
# ['district', 'piccadilly']
# ['metropolitan']
# ['district']
# ['district']
# ['district']
# ['district']
# []
# []
# ['hammersmith']
# ['circle']
# ['circle']
# ['district', 'hammersmith']
# ['circle']
# ['district']
# ['circle', 'district']
# ['circle', 'district']
# ['circle']
# ['circle', 'district']
# []
# []
# []
# ['district']
# ['district']
# ['district']
# ['district']
# ['metropolitan']
# ['metropolitan']
# ['metropolitan']
# ['northern']
# []
# ['northern']
# ['northern']
# ['northern']
# []
# []
# ['metropolitan']
# ['metropolitan']
# []
# []
# ['northern']
# []
# ['northern']
# ['northern']
# ['northern']
# ['northern']
# ['central']
# ['central']
# ['central']
# ['central']
# ['central']
# ['central']
# ['central']
# ['central']
# ['central']
# []
# []
# ['central']
# []
# ['central']
# []
# ['northern']
# ['northern']
# ['northern']
# ['district', 'hammersmith']
# []
# ['district', 'hammersmith']
# ['district', 'hammersmith']
# ['district', 'hammersmith']
# ['district', 'hammersmith']
# ['district', 'hammersmith']
# ['district', 'hammersmith']
# ['district', 'hammersmith']
# []
# []
# ['district', 'hammersmith']
# []
# []
# []
# ['metropolitan', 'piccadilly']
# []
# ['district']
# ['district']
# ['piccadilly']
# ['piccadilly']
# ['northern']
# ['piccadilly']
# ['piccadilly']
# ['waterloo']
# ['bakerloo', 'northern']
# ['bakerloo']
# ['piccadilly']
# ['piccadilly']
# ['piccadilly']
# ['piccadilly']
# ['piccadilly']
# ['piccadilly']
# ['central']
# ['northern']
# []
# ['piccadilly']
# ['northern']
# ['piccadilly']
# []
# ['bakerloo']
# ['bakerloo']
# ['piccadilly']
# ['piccadilly']
# ['piccadilly']
# ['piccadilly']
# ['bakerloo']
# ['piccadilly']
# ['piccadilly']
# ['bakerloo', 'northern']
# ['bakerloo']
# ['piccadilly']
# ['piccadilly']
# []
# ['bakerloo']
# ['piccadilly']
# ['piccadilly']
# ['piccadilly']
# ['piccadilly']
# ['metropolitan', 'piccadilly']
# []
# ['central']
# ['piccadilly']
# []
# ['bakerloo']
# ['bakerloo']
# ['northern', 'victoria']
# ['piccadilly']
# ['northern']
# ['northern']
# ['northern']
# ['northern']
# ['northern']
# ['northern']
# ['northern']
# ['northern']
# ['northern', 'victoria']
# ['northern']
# ['northern']
# ['piccadilly']
# ['northern']
# ['northern']
# []
# ['metropolitan']
# ['piccadilly']
# ['piccadilly']
# ['piccadilly']
# ['piccadilly']
# ['metropolitan']
# ['metropolitan']
# ['district']
# ['district']
# ['metropolitan', 'piccadilly']
# ['metropolitan', 'piccadilly']
# ['metropolitan']
# ['metropolitan']
# ['hammersmith']
# ['hammersmith']
# ['bakerloo']
# []
# ['bakerloo']
# ['bakerloo']
# ['bakerloo']
# ['metropolitan']
# ['metropolitan']
# ['bakerloo']
# ['bakerloo']
# ['bakerloo']
# ['bakerloo']
# []
# ['bakerloo']
# ['bakerloo']
# ['bakerloo']
# []
# []
# ['northern']
# ['northern']
# ['metropolitan', 'piccadilly']
# ['metropolitan']
# ['central']
# ['metropolitan']
# ['central']
# ['central']
# ['metropolitan', 'piccadilly']
# ['northern']
# ['northern']
# ['northern']
# ['metropolitan']
# ['metropolitan']
# ['northern']
# ['northern']
# ['northern']
# ['northern']
# ['northern']
# ['northern']
# ['northern']
# ['district']
# ['district']
# ['district']
# ['piccadilly']
# ['piccadilly']
# ['piccadilly']
# ['piccadilly']
# ['piccadilly']
# ['district']
# ['piccadilly']
# ['bakerloo']
# ['bakerloo']
# ['metropolitan']
# ['piccadilly']
# ['piccadilly']
# ['metropolitan']
# ['district']
# ['district']
# ['district']
# ['district']
# []
# ['northern']
# ['northern']
# ['northern']
# ['northern']
# ['northern']
# ['northern']
# ['northern']
# ['northern']
# ['central']
# ['central']
# ['central']
# ['central']
# ['central']
# ['central']
# ['central']
# ['central']
# ['central']
# ['central']
# ['central']
# []
# ['central']
# ['central']
# ['central']
# ['central']
# ['central']
# ['central']
# ['central']
# ['central']
# ['central']
# ['central']
# ['central']
# ['central']
# ['central']
# ['central']
# ['central']
# ['central']
# ['central']
# ['central']
# ['central']
# ['central']
# ['central']
# ['central']
# []
# ['victoria']
# ['victoria']
# ['victoria']
# ['victoria']
# ['victoria']
# ['victoria']
# ['victoria']
# ['victoria']
# ['victoria']
# ['victoria']
# ['victoria']
# []
# ['victoria']
# ['victoria']
# ['piccadilly']
# ['piccadilly']
# ['jubilee']
# ['jubilee']
# ['jubilee']
# ['jubilee']
# ['jubilee']
# ['jubilee']
# []
# ['jubilee']
# []
# ['jubilee']
# ['jubilee']
# ['jubilee']
# ['jubilee']
# ['jubilee']
# ['jubilee']
# ['jubilee']
# ['jubilee']
# ['jubilee']
# ['jubilee']
# ['jubilee']
# ['piccadilly']
# ['piccadilly']
# []
# ['jubilee']
# ['jubilee']
# ['jubilee']
# ['jubilee']
# ['jubilee']
# ['jubilee']
# ['jubilee']
# ['jubilee']
# ['piccadilly']
# ['hammersmith']
# ['hammersmith']
# before reset id (408, 6)
# after reset id (408, 4)
# /home/william/complex_networks/projects/data_project/helper_functions.py:340: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   stations_grouped[0] = stations_grouped[0][stations_grouped[0] != 'Roosevel']
# /home/william/complex_networks/projects/data_project/helper_functions.py:340: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   stations_grouped[0] = stations_grouped[0][stations_grouped[0] != 'Roosevel']
